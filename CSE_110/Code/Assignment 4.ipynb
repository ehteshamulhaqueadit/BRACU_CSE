# %% [markdown]
# Task 1

# %%
user=str(input("Please enter the string...."))
count=len(user)
while (count-1)>=0:
    print(user[count-1],end="")
    count-=1

# %% [markdown]
# Task 2

# %%
user=str(input("Please enter the string...."))
index=int(input("Please enter the index number...."))
count=len(user)
ind=index
while ind>=0:
    print(ind,end="")
    ind-=1
while (index+1)<=(count-1):
    print(user[index+1],end="")

# %% [markdown]
# Task 3

# %%
user=str(input("Please enter the string...."))
for i in user:
  if i=="0":
    final=1
  elif i=="1":
    final=1
  else:
    final=0
    break
if final==1:
  print("Binary Number")
if final==0:
  print("Not a Binary Number")

# %% [markdown]
# Task 4

# %%
user=input("Enter a word...")
if len(user)<4:
  if user.endswith("er"):
    print(user.replace("er","est"))
  else:
    print(user)
elif user.endswith("er"):
  print(user.replace("er","est"))
elif user.endswith("est"):
  print(user)
else:
  print(user+"er")

# %% [markdown]
# Task 5

# %%
user=input("Enter a word...")
count=len(user)+1
for i in range(0,(count)):
    for j in range(0,i):
        print(user[j],end="")
    print("")

# %% [markdown]
# Task 6

# %%
user=input("enter the word...")
ind=len(user)
for i in range(ind):
    print(user[i]," : ",ord(user[i]))

# %% [markdown]
# Task 7

# %%
user=input("enter the word...")
ind=len(user)
sum=""
for i in range(ind):
    asci=(ord(user[i]))
    if asci==122:
        asci=96
    if asci==90:
        asci=64
    sum=sum+(chr(asci+1))
print(sum)

# %% [markdown]
# Task 8

# %%
user=input("enter the word...")
ind=len(user)
sum=""
for i in range(ind):
    if i%2!=0:
        sum=sum+(chr(((ord(user[i]))-32)))
print(sum)

# %% [markdown]
# Task 9

# %%
user=input("enter the word...")
sum=""
same=""
for i in user:
  if i!=same:
    sum+=i
  same=i
print(sum)

# %% [markdown]
# Task 10

# %%
user=input("Enter two string with comma")
str1=user[:user.find(",")]
if " " in user:
  str2=user[user.find(",")+2:]
else:
  str2=user[user.find(",")+1:]
  
count=0
if len(str1)>len(str2):
    count= len(str2)
    ending= str1[count:]
else:
    count= len(str1)
    ending= str2[count:]
for i in range(count):
    print(str1[i],end="")
    print(str2[i],end="")
print(ending)
